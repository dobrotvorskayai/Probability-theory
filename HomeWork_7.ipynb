# %% [markdown]
# Выбрать тест и проверить, есть  ли различия между выборками:
#
# 1 )  Даны две  независимые выборки. Не соблюдается условие нормальности
#
# x1  380,420, 290
#
# y1 140,360,200,900
#
# Сделайте вывод по результатам, полученным с помощью функции

# %%
import numpy as np
from scipy import stats

A = np.array([380, 420, 290])
B = np.array([140, 360, 200, 900])
stats.mannwhitneyu(A, B)
# Out:
# MannwhitneyuResult(statistic=8.0, pvalue=0.6285714285714286)

# %% [markdown]
# Так как pvalue > 0,05, принимаем нулевую гипотезу, что статистическизначимые отличия НЕ существуют.

# %% [markdown]
# 2 ) Исследовалось влияние препарата на уровень давления пациентов. Сначала измерялось давление до приема препарата, потом через 10 минут и через 30 минут. Есть ли статистически значимые различия?
#
# 1е измерение до приема препарата: 150, 160, 165, 145, 155
#
# 2е измерение через 10 минут: 140, 155, 150,  130, 135
#
# 3е измерение через 30 минут: 130, 130, 120, 130, 125

# %%
import numpy as np
from scipy import stats

A = np.array([150, 160, 165, 145, 155])
B = np.array([140, 155, 150,  130, 135])
C = np.array([130, 130, 120, 130, 125])
stats.friedmanchisquare(A, B, C)
# Out:
# FriedmanchisquareResult(statistic=9.578947368421062, pvalue=0.00831683351100441)

# %% [markdown]
# Так как pvalue < 0,05, принимаем альтернативную гипотезу, что статистическизначимые отличия существуют.

# %% [markdown]
# 3 ) Сравните 1 и 2 е измерения, предполагая, что 3го измерения через 30 минут не было.

# %%
import numpy as np
from scipy import stats

A = np.array([150, 160, 165, 145, 155])
B = np.array([140, 155, 150,  130, 135])
stats.wilcoxon(A, B)
# Out:
# WilcoxonResult(statistic=0.0, pvalue=0.0625)

# %% [markdown]
# Так как pvalue > 0,05, принимаем нулевую гипотезу, что статистическизначимые отличия НЕ существуют.

# %% [markdown]
# 4) Даны 3 группы  учеников плавания.
#
# В 1 группе время на дистанцию 50 м составляют:
#
# 56, 60, 62, 55, 71, 67, 59, 58, 64, 67
#
# Вторая группа : 57, 58, 69, 48, 72, 70, 68, 71, 50, 53
#
# Третья группа: 57, 67, 49, 48, 47, 55, 66, 51, 54

# %%
import numpy as np
from scipy import stats

A = np.array([56, 60, 62, 55, 71, 67, 59, 58, 64, 67])
B = np.array([57, 58, 69, 48, 72, 70, 68, 71, 50, 53])
C = np.array([57, 67, 49, 48, 47, 55, 66, 51, 54])
stats.kruskal(A, B, C)
# Out:
# KruskalResult(statistic=5.465564058257224, pvalue=0.0650380998590494)

# %% [markdown]
# Так как pvalue > 0,05, принимаем нулевую гипотезу, что статистическизначимые отличия НЕ существуют.

# %% [markdown]
# 5) Заявляется, что партия изготавливается со средним арифметическим 2,5 см. Проверить данную гипотезу, если известно, что размеры изделий подчинены нормальному закону распределения. Объем выборки 10, уровень статистической значимости 5%
#
# 2.51, 2.35, 2.74, 2.56, 2.40, 2.36, 2.65, 2.7, 2.67, 2.34

# %% [markdown]
# Среднее арифметическое выборки равно:

# %%
print (((2.51 + 2.35 + 2.74 + 2.56 + 2.40 + 2.36 + 2.65 + 2.7 + 2.67 + 2.34)/10))
# Out:
# 2.5279999999999996

# %% [markdown]
# Дисперсия равна:

# %%
print ((((2.51-2.53)**2 + (2.35-2.53)**2 + (2.74-2.53)**2 + (2.56-2.53)**2 + (2.40-2.53)**2 + (2.36-2.53)**2 + (2.65-2.53)**2 + (2.7-2.53)**2 + (2.67-2.53)**2 + (2.34-2.53)**2)/(10-1)))
# Out:
# 0.024733333333333354

# %% [markdown]
# Наблюдаемый критерий t равен:

# %%
print ((2.53-2.5)/((0.025**0.5)/(10**0.5)))
# Out:
# 0.5999999999999961

# %% [markdown]
# Табличный критерий t равен 1.83
# Так как Табличное значение больше наблюдаемого, принимается нулевая гипотеза
